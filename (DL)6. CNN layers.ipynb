# %% [markdown]
# # <center> <h1> 👨‍💻

# %% [markdown]
# # <center> CNN - Convolution neural network
# * ### A convolutional neural network is a special architecture of artificial neural networks proposed by Yann LeCun in 1988 to efficiently detect patterns and is part of deep learning technologies.
#
# Its name is so called because of the existence of a convolution operation, the essence of which is that each image piece is multiplied by the element of the convolution matrix (kernel), and the result is summarized, and the output is written to a similar position of the image.

# %% [markdown]
# Let's first learn how to calculate a filter
#
# ![%D0%94%D0%B8%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0%20%D0%B1%D0%B5%D0%B7%20%D0%BD%D0%B0%D0%B7%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F%282%29.jpg](attachment:%D0%94%D0%B8%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0%20%D0%B1%D0%B5%D0%B7%20%D0%BD%D0%B0%D0%B7%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F%282%29.jpg)
#
# `That is, the corresponding elements are multiplied and added at the end.`

# %% [markdown]
# ### We apply padding="same" before starting the calculation above. What is this ?
# ### Padding (`we fill the surroundings with 0s`) to keep the image from losing its size in CNN. If we apply a filter to the image itself, the size of the image will be reduced, which may cause us to lose the features we need. Our images are mainly 3-dimensional, so our filter (kernel) should be 3-dimensional as well.
#
# ![%D0%94%D0%B8%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0%20%D0%B1%D0%B5%D0%B7%20%D0%BD%D0%B0%D0%B7%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F%283%29.jpg](attachment:%D0%94%D0%B8%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0%20%D0%B1%D0%B5%D0%B7%20%D0%BD%D0%B0%D0%B7%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F%283%29.jpg)
#
# `Depth is the number of picture channels.`

# %% [markdown]
# ![%D0%94%D0%B8%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0%20%D0%B1%D0%B5%D0%B7%20%D0%BD%D0%B0%D0%B7%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F%284%29.jpg](attachment:%D0%94%D0%B8%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0%20%D0%B1%D0%B5%D0%B7%20%D0%BD%D0%B0%D0%B7%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F%284%29.jpg)

# %% [markdown]
# ### For example, we have the following image of size 5 x 5.

# %% [markdown]
# ![%D0%94%D0%B8%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0%20%D0%B1%D0%B5%D0%B7%20%D0%BD%D0%B0%D0%B7%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F%285%29.jpg](attachment:%D0%94%D0%B8%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0%20%D0%B1%D0%B5%D0%B7%20%D0%BD%D0%B0%D0%B7%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F%285%29.jpg)

# %% [markdown]
# ### Image consists of 3 channels (RGB)

# %% [markdown]
# ![%D0%94%D0%B8%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0%20%D0%B1%D0%B5%D0%B7%20%D0%BD%D0%B0%D0%B7%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F%286%29515.jpg](attachment:%D0%94%D0%B8%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0%20%D0%B1%D0%B5%D0%B7%20%D0%BD%D0%B0%D0%B7%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F%286%29515.jpg)

# %% [markdown]
# ### <center> First, we apply padding (that is, we fill each channel of the image with 0s. As we mentioned above, this is necessary in order not to lose the size of the incoming image)

# %% [markdown]
# ![%D0%94%D0%B8%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0%20%D0%B1%D0%B5%D0%B7%20%D0%BD%D0%B0%D0%B7%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F%286%2948.jpg](attachment:%D0%94%D0%B8%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0%20%D0%B1%D0%B5%D0%B7%20%D0%BD%D0%B0%D0%B7%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F%286%2948.jpg)

# %% [markdown]
# ### <center> A filter is applied to each channel.

# %% [markdown]
# ![%D0%94%D0%B8%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0%20%D0%B1%D0%B5%D0%B7%20%D0%BD%D0%B0%D0%B7%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F%286%291484.jpg](attachment:%D0%94%D0%B8%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0%20%D0%B1%D0%B5%D0%B7%20%D0%BD%D0%B0%D0%B7%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F%286%291484.jpg)

# %% [markdown]
# ### <center> Calculate and write the output value to the image

# %% [markdown]
# ![%D0%94%D0%B8%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0%20%D0%B1%D0%B5%D0%B7%20%D0%BD%D0%B0%D0%B7%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F%286%29486.jpg](attachment:%D0%94%D0%B8%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0%20%D0%B1%D0%B5%D0%B7%20%D0%BD%D0%B0%D0%B7%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F%286%29486.jpg)

# %% [markdown]
# ### `Bias is added randomly, but mostly 1 is used.`

# %% [markdown]
# ### <center> Overall result

# %% [markdown]
# ![%D0%94%D0%B8%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0%20%D0%B1%D0%B5%D0%B7%20%D0%BD%D0%B0%D0%B7%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F%286%298545.jpg](attachment:%D0%94%D0%B8%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0%20%D0%B1%D0%B5%D0%B7%20%D0%BD%D0%B0%D0%B7%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F%286%298545.jpg)

# %% [markdown]
# ### <center> In the example above, we used 1 filter per channel. If we use 3 filters for each channel, it will be as follows.

# %% [markdown]
# ![%D0%94%D0%B8%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0%20%D0%B1%D0%B5%D0%B7%20%D0%BD%D0%B0%D0%B7%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F%286%291848.jpg](attachment:%D0%94%D0%B8%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0%20%D0%B1%D0%B5%D0%B7%20%D0%BD%D0%B0%D0%B7%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F%286%291848.jpg)

# %% [markdown]
# ### <center> So after passing through the 3d filter, each channel will produce a 1d image and this will give us 1 3d image at the end

# %% [markdown]
# ![%D0%94%D0%B8%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0%20%D0%B1%D0%B5%D0%B7%20%D0%BD%D0%B0%D0%B7%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F%286%2984848448.jpg](attachment:%D0%94%D0%B8%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0%20%D0%B1%D0%B5%D0%B7%20%D0%BD%D0%B0%D0%B7%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F%286%2984848448.jpg)

# %% [markdown]
# `Note the image below` In the output image (convoluted image), after calculations, the values remain higher than 255. We know that images take values from 0 to 255. What will happen in this case ?
#
# In this case we can take values greater than 255 as 255 and values less than 0 as 0. But this is not a very good way. A good way is to NORMALIZATION i.e. divide the image values (pixel values) by the largest value i.e. 255, which helps us bring the pixel values between 0 and 1 [0,1].
#
# ![%D0%94%D0%B8%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0%20%D0%B1%D0%B5%D0%B7%20%D0%BD%D0%B0%D0%B7%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F%286%292626.jpg](attachment:%D0%94%D0%B8%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0%20%D0%B1%D0%B5%D0%B7%20%D0%BD%D0%B0%D0%B7%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F%286%292626.jpg)

# %% [markdown]
# ### <center> Max pooling - returns the maximum value from the part of the image covered by the kernel.
#
# max pooling kernel size = 2 (reduces the image by 2 times)

# %% [markdown]
# ![%D0%94%D0%B8%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0%20%D0%B1%D0%B5%D0%B7%20%D0%BD%D0%B0%D0%B7%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F%286%299894.jpg](attachment:%D0%94%D0%B8%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0%20%D0%B1%D0%B5%D0%B7%20%D0%BD%D0%B0%D0%B7%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F%286%299894.jpg)

# %% [markdown]
# ### <center> Max pooling returns the largest based on kernel size. This is used to make the image smaller

# %% [markdown]
# ### The question is how many parameters are there in this picture ?

# %% [markdown]
# ![%D0%94%D0%B8%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0%20%D0%B1%D0%B5%D0%B7%20%D0%BD%D0%B0%D0%B7%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F%286%2984848448.jpg](attachment:%D0%94%D0%B8%D0%B0%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B0%20%D0%B1%D0%B5%D0%B7%20%D0%BD%D0%B0%D0%B7%D0%B2%D0%B0%D0%BD%D0%B8%D1%8F%286%2984848448.jpg)

# %% [markdown]
# ### Answer - There are 84 parameters.
#
# Each 3d filter consists of 1d(3x3) filters in 3, i.e. 3D Filter 1
#
# There are 9*3=27 parameters. and one bias is added to each 3d filter
#
# ((3 * 3 * 3) + 1) * 3 = 84
#
# If we make a formula
#
# ((kernel.height * kernel.width * old.kernel.size) + 1 ) * 3d.kernels.number) = number of parameters

# %% [markdown]
# ### <center> In CNN the weights are numbers in the kernel (filter).

# %% [markdown]
# # <center> <h1> 👨‍💻   🚀
